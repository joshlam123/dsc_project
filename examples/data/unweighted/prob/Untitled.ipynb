# %%
import json
import networkx

# %%
# with open('data.txt') as json_file:
#     data = json.load(json_file)
with open('rand5.json') as f:
    file = json.load(f)

file
# Out:
# {'edges': {'0': [{'VerticeId': 2, 'Value': 0}, {'VerticeId': 3, 'Value': 0}],
#   '1': [{'VerticeId': 2, 'Value': 0},
#    {'VerticeId': 3, 'Value': 0},
#    {'VerticeId': 4, 'Value': 4},
#    {'VerticeId': 0, 'Value': 2}],
#   '2': [{'VerticeId': 3, 'Value': 0},
#    {'VerticeId': 1, 'Value': 2},
#    {'VerticeId': 4, 'Value': 4}],
#   '3': [{'VerticeId': 1, 'Value': 2},
#    {'VerticeId': 4, 'Value': 4},
#    {'VerticeId': 0, 'Value': 2},
#    {'VerticeId': 2, 'Value': 0}],
#   '4': [{'VerticeId': 2, 'Value': 0},
#    {'VerticeId': 0, 'Value': 2},
#    {'VerticeId': 3, 'Value': 0},
#    {'VerticeId': 1, 'Value': 2}]},
#  'info': {'Name': 'rand', 'NumVertices': 5},
#  'vertices': {'0': {'Name': '0', 'Value': 2},
#   '1': {'Name': '1', 'Value': 2},
#   '2': {'Name': '2', 'Value': 0},
#   '3': {'Name': '3', 'Value': 0},
#   '4': {'Name': '4', 'Value': 4}}}

# %%
import networkx as nx
G = nx.Graph()

for k,v in file['vertices'].items():
    G.add_node(v['Name'], value=v['Value'])
    for m in file['edges'][k]:
        G.add_edge(k, m['VerticeId'])
        
# nx.draw(G, with_labels=True, font_weight='bold')
options={"node_color":"blue"}
# nx.draw_shell(G, with_labels=True, font_weight='bold', **options)
# options = {'node_size': 200,'width': 3}

# nx.draw_spectral(G, **options)
nx.draw(G, with_labels=True, font_weight='bold')
# plt.subplot(122)
